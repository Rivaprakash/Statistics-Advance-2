# %% [markdown]
# 1. What is hypothesis testing in statistics?
#
# Ans- Hypothesis testing is a way to check if a claim about a dataset is true. It uses sample data to decide whether to accept or reject a hypothesis based on probability.

# %% [markdown]
# 2. What is the null hypothesis, and how does it differ from the alternative hypothesis?
#
# Ans- Null Hypothesis (H₀) assumes no effect or no difference (status quo).
#
# * Alternative Hypothesis (H₁): Claims there is an effect or difference.
#
# * Hypothesis testing checks if we have enough evidence to reject H₀ in favor of H₁.

# %% [markdown]
# 3. What is the significance level in hypothesis testing, and why is it important?
#
# Ans- The significance level (α) is the probability of rejecting the null hypothesis (H₀) when it is actually true. Common values are 0.05 or 0.01. It helps control the risk of making a Type I error (false positive).

# %% [markdown]
# 4. What does a P-value represent in hypothesis testing?
#
# Ans- The P-value shows the probability of getting the observed results if the null hypothesis (H₀) is true.
#
# * Low P-value (≤ α) → Reject H₀ (strong evidence against it).
#
# * High P-value (> α) → Fail to reject H₀ (not enough evidence).
#
# It helps decide whether a result is statistically significant.

# %% [markdown]
# 5. How do you interpret the P-value in hypothesis testing?
#
# Ans- The P-value shows how likely the result is due to chance. A small P-value (≤ 0.05) means strong evidence against H₀, so we reject it. A large P-value (> 0.05) means not enough evidence, so we keep H₀.

# %% [markdown]
# 6. What are Type 1 and Type 2 errors in hypothesis testing.
#
# Ans- In hypothesis testing, a Type 1 error occurs when we wrongly reject a true null hypothesis (H₀), leading to a false positive.
#
# A Type 2 error happens when we fail to reject a false H₀, leading to a false negative. Lowering one often increases the other.

# %% [markdown]
# 7. What is the difference between a one-tailed and a two-tailed test in hypothesis testing?
#
# Ans- A one-tailed test checks if a value is only greater or only smaller than a given value.
#
# A two-tailed test checks if a value is either greater or smaller than a given value.
#
# Use a one-tailed test when you expect a specific direction.
#
# Use a two-tailed test when you just want to check for any difference.

# %% [markdown]
# 8. What is the Z-test, and when is it used in hypothesis testing?
#
# Ans- A Z-test is a statistical test used to compare sample and population means when the population variance is known and the sample size is large (usually ≥ 30).
#
# When to use:
#
# * To test if a sample mean is different from a population mean.
#
# * To compare two sample means when population variances are known.
#
# * When data follows a normal distribution or the sample is large.

# %% [markdown]
# 9. How do you calculate the Z-score, and what does it represent in hypothesis testing?
#
# Ans- Formula for Z-score:
#
# 𝑍 = (𝑋−𝜇)/𝜎
#
# Where:
#
# X = Sample value
#
# μ = Population mean
#
# σ = Population standard deviation
#
# It Represents:
# * The Z-score shows how many standard deviations a value is from the mean.
#
# * In hypothesis testing, it helps decide whether to reject the null hypothesis based on a critical Z-value.

# %% [markdown]
# 10. What is the T-distribution, and when should it be used instead of the normal distribution?
#
# Ans- The T-distribution is a probability distribution used when the sample size is small (n < 30) and the population standard deviation is unknown. It is similar to the normal distribution but has fatter tails.
#
# When to Use It:
#
# * When sample size is small (n < 30).
#
# * When population standard deviation (σ) is unknown.
#
# * In T-tests for comparing means.
#
# For large samples (n ≥ 30), the T-distribution becomes close to the normal distribution.

# %% [markdown]
# 11. What is the difference between a Z-test and a T-test?
#
# Ans- The difference between a Z-test and a T-test:
#
# * Z-test is used for large samples (n ≥ 30), while T-test is for small samples (n < 30).
#
# * Z-test requires known population standard deviation (σ), but T-test works when σ is unknown.
#
# * Z-test follows the normal distribution, while T-test follows the T-distribution (which has wider tails).
#
# * Z-test is used for comparing means with a known population, while T-test is for small sample mean comparisons.

# %% [markdown]
# 12. What is the T-test, and how is it used in hypothesis testing?
#
# Ans-A T-test is a statistical test used to compare means when the sample size is small (n < 30) and the population standard deviation is unknown.
#
# It's Used in Hypothesis Testing:
# * Set hypotheses:
#
# Null hypothesis (H₀): No difference between means.
#
# Alternative hypothesis (H₁): There is a difference.
#
# * Compare with the critical T-value from the T-table.
#
# * Decide:
#
# If T-score > critical value, reject H₀.
#
# If T-score ≤ critical value, fail to reject H₀.

# %% [markdown]
# 13. What is the relationship between Z-test and T-test in hypothesis testing?
#
# Ans- The relationship between Z-test and T-test in hypothesis testing:
#
# * Both test means but under different conditions (Z-test for large samples, T-test for small samples).
#
# * T-test is used when σ is unknown, while Z-test requires a known σ.
#
# * As sample size increases (n ≥ 30), the T-distribution becomes similar to the normal distribution, making the T-test approach the Z-test.
#
# * Both follow the same hypothesis testing steps, using different distributions for critical values.

# %% [markdown]
# 14. What is a confidence interval, and how is it used to interpret statistical results?
#
# Ans-A confidence interval is a range of values that likely contains the true population parameter with a certain level of confidence (e.g., 95%).
#
# How It's Used:
# * Gives an estimate instead of a single value.
# * Helps in decision-making—if a hypothesized value (e.g., population mean) falls outside the CI, it may be rejected.
# * Example: A 95% CI of (50, 60) means we are 95% confident the true value lies between 50 and 60.

# %% [markdown]
# 15. What is the margin of error, and how does it affect the confidence interval?
#
# Ans-The margin of error is the amount by which the sample estimate may vary from the true population value.
#
# How It Affects Confidence Interval:
# * Larger MOE → Wider CI (less precise).
# * Smaller MOE → Narrower CI (more precise).
# * Reducing MOE: Increase sample size (n) or decrease variability (σ).

# %% [markdown]
# 16. How is Bayes' Theorem used in statistics, and what is its significance?
#
# Ans- Bayes' Theorem is used to update probabilities based on new information.
#
# Significance:
# * Used in spam detection, medical diagnosis, and machine learning.
# * Helps revise predictions based on new data.
# * Improves decision-making under uncertainty.

# %% [markdown]
# 17. What is the Chi-square distribution, and when is it used?
#
# Ans-The Chi-square distribution is a probability distribution used for categorical data analysis. It is right-skewed and depends on degrees of freedom (df).
#
# When It Is Used:
# * Chi-Square Goodness of Fit Test – Checks if observed data matches expected data.
# * Chi-Square Test for Independence – Tests if two categorical variables are related.
# * Chi-Square Test for Variance – Compares sample variance to population variance.

# %% [markdown]
# 18. What is the Chi-square goodness of fit test, and how is it applied?
#
# Ans- This test checks if observed data follows a expected distribution.
#
# How It Is Applied:
# * Set Hypotheses:
#
# H₀ (Null): Observed data follows the expected distribution.
#
# H₁ (Alternative): Observed data does not match the expected distribution.
#
# * Compare with Critical Value:
#
# If χ² > critical value, reject H₀.
#
# If χ² ≤ critical value, fail to reject H₀.
#
# * Application: Used in genetics, marketing, and quality control to test distributions.

# %% [markdown]
# 19. What is the F-distribution, and when is it used in hypothesis testing?
#
# Ans- The F-distribution is a right-skewed probability distribution used to compare variances of two datasets. It depends on two degrees of freedom (df₁, df₂).
#
# When It Is Used:
# * ANOVA (Analysis of Variance) – Compares multiple group means.
# * F-Test for Variance – Compares variances of two populations.
# * Regression Analysis – Tests overall model significance

# %% [markdown]
# 20. What is an ANOVA test, and what are its assumptions?
#
# Ans-ANOVA is used to compare means of three or more groups to see if they are significantly different.
#
# Assumptions of ANOVA:
# * Independence – Samples must be independent.
#
# * Normality – Data should be normally distributed.
#
# * Homogeneity of Variance – All groups should have equal variances (checked using Levene’s test).

# %% [markdown]
# 21. What are the different types of ANOVA tests?
#
# Ans- The different types of ANOVA tests:
#
# * One-Way ANOVA: Compares means of three or more groups based on one independent variable.
#
# * Two-Way ANOVA: Compares means based on two independent variables to check their individual and combined effects.
#
# * Repeated Measures ANOVA: Compares means when the same subjects are tested multiple times.
#
# * MANOVA (Multivariate ANOVA): Used when there are multiple dependent variables instead of one.

# %% [markdown]
# 22. What is the F-test, and how does it relate to hypothesis testing?
#
# Ans- An F-test is used to compare variances or multiple means in hypothesis testing. It follows the F-distribution.
#
# How It Relates to Hypothesis Testing:
# * Tests Variance Equality – Checks if two populations have the same variance.
#
# * Used in ANOVA – Determines if group means are significantly different.

# %%
#1. Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and interpret the results

from scipy.stats import norm
import numpy as np

def z_test(sample, pop_mean, pop_std):
    z = (np.mean(sample) - pop_mean) / (pop_std / np.sqrt(len(sample)))
    p = 2 * (1 - norm.cdf(abs(z)))
    return z, p

sample = [52, 55, 53, 50, 49, 51, 54, 56, 48, 47]
z, p = z_test(sample, 50, 5)
print(f"Z-score: {z:.4f}, P-value: {p:.4f}")
print("Reject H₀" if p < 0.05 else "Fail to reject H₀")
# Out:
# Z-score: 0.9487, P-value: 0.3428
# Fail to reject H₀

# %%
#2. Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python.

import numpy as np
from scipy.stats import ttest_1samp

# Simulate random sample data
np.random.seed(42)  # For reproducibility
sample = np.random.normal(loc=50, scale=5, size=30)  # Mean=50, Std=5, n=30

# Perform one-sample t-test
pop_mean = 50  # Hypothetical population mean
t_stat, p_value = ttest_1samp(sample, pop_mean)

print(f"T-statistic: {t_stat:.4f}, P-value: {p_value:.4f}")
print("Reject H₀" if p_value < 0.05 else "Fail to reject H₀")
# Out:
# T-statistic: -1.1450, P-value: 0.2616
# Fail to reject H₀

# %%
#3. Implement a one-sample Z-test using Python to compare the sample mean with the population mean.

import numpy as np
from scipy.stats import norm

def one_sample_z_test(sample, pop_mean, pop_std):
    z = (np.mean(sample) - pop_mean) / (pop_std / np.sqrt(len(sample)))
    p = 2 * (1 - norm.cdf(abs(z)))
    return z, p

# Simulate random sample data
np.random.seed(42)
sample = np.random.normal(loc=50, scale=5, size=30)  # Mean=50, Std=5, n=30

# Perform one-sample Z-test
z_score, p_value = one_sample_z_test(sample, 50, 5)

print(f"Z-score: {z_score:.4f}, P-value: {p_value:.4f}")
print("Reject H₀" if p_value < 0.05 else "Fail to reject H₀")
# Out:
# Z-score: -1.0305, P-value: 0.3028
# Fail to reject H₀

# %%
#4. Perform a two-tailed Z-test using Python and visualize the decision region on a plot.

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

np.random.seed(42)
sample = np.random.normal(50, 5, 30)
z = (np.mean(sample) - 50) / (5 / np.sqrt(len(sample)))
p = 2 * (1 - norm.cdf(abs(z)))

x = np.linspace(-4, 4, 1000)
y = norm.pdf(x)
cv = norm.ppf(0.975)
plt.plot(x, y)
plt.axvline(z, color='r', linestyle='dashed', label=f'Z={z:.2f}')
plt.axvline(cv, color='g', linestyle='dashed', label='±1.96')
plt.axvline(-cv, color='g', linestyle='dashed')
plt.fill_between(x, y, where=(x > cv) | (x < -cv), color='red', alpha=0.3)
plt.legend()
plt.show()

print(f"Z-score: {z:.4f}, P-value: {p:.4f}")
print("Reject H₀" if p < 0.05 else "Fail to reject H₀")
# Out:
# Z-score: -1.0305, P-value: 0.3028
# Fail to reject H₀

# %%
#5. Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing.
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def visualize_errors(alpha=0.05, beta=0.2):
    x = np.linspace(-4, 4, 1000)
    plt.plot(x, norm.pdf(x), 'b', label='H₀')
    plt.plot(x, norm.pdf(x, loc=2), 'r', label='H₁')
    cv = norm.ppf(1 - alpha)
    plt.fill_between(x, norm.pdf(x), where=(x > cv), color='blue', alpha=0.3, label='Type 1 Error (α)')
    plt.fill_between(x, norm.pdf(x, loc=2), where=(x < cv), color='red', alpha=0.3, label='Type 2 Error (β)')
    plt.axvline(cv, color='black', linestyle='dashed', label='Critical Value')
    plt.legend(), plt.title("Type 1 & Type 2 Errors"), plt.show()

visualize_errors()

# %%
#6. Write a Python program to perform an independent T-test and interpret the results.
import numpy as np
from scipy.stats import ttest_ind

# Simulate random sample data
np.random.seed(42)
group1 = np.random.normal(50, 5, 30)
group2 = np.random.normal(52, 5, 30)

# Perform independent T-test
t_stat, p_value = ttest_ind(group1, group2)

# Print results
print(f"T-statistic: {t_stat:.4f}, P-value: {p_value:.4f}")
print("Reject H₀" if p_value < 0.05 else "Fail to reject H₀")
# Out:
# T-statistic: -1.9752, P-value: 0.0530
# Fail to reject H₀

# %%
#7. Perform a paired sample T-test using Python and visualize the comparison results.

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_rel

np.random.seed(42)
before = np.random.normal(50, 5, 30)
after = before + np.random.normal(1, 2, 30)  # Small effect

t_stat, p_value = ttest_rel(before, after)

plt.figure(figsize=(6, 4))
plt.scatter(before, after, color='blue', alpha=0.6, label='Paired Samples')
plt.plot([40, 60], [40, 60], 'r--', label='y = x (No Change)')
plt.xlabel("Before Treatment")
plt.ylabel("After Treatment")
plt.legend()
plt.title("Paired Sample Comparison")
plt.show()

print(f"T-statistic: {t_stat:.4f}, P-value: {p_value:.4f}")
print("Reject H₀" if p_value < 0.05 else "Fail to reject H₀")
# Out:
# T-statistic: -2.2285, P-value: 0.0338
# Reject H₀

# %%
#8. Simulate data and perform both Z-test and T-test, then compare the results using Python.

import numpy as np
from scipy.stats import ttest_1samp, norm

np.random.seed(42)
sample = np.random.normal(50, 5, 30)
z_stat = (np.mean(sample) - 50) / (5 / np.sqrt(len(sample)))
z_p = 2 * (1 - norm.cdf(abs(z_stat)))
t_stat, t_p = ttest_1samp(sample, 50)

print(f"Z-test: Z={z_stat:.4f}, P={z_p:.4f}\nT-test: T={t_stat:.4f}, P={t_p:.4f}")
print("Z-test: Reject H₀" if z_p < 0.05 else "Z-test: Fail to reject H₀")
print("T-test: Reject H₀" if t_p < 0.05 else "T-test: Fail to reject H₀")
# Out:
# Z-test: Z=-1.0305, P=0.3028
# T-test: T=-1.1450, P=0.2616
# Z-test: Fail to reject H₀
# T-test: Fail to reject H₀

# %%
#9. Write a Python function to calculate the confidence interval for a sample mean and explain its significance.

import numpy as np
from scipy.stats import norm

def confidence_interval(sample, confidence=0.95):
    mean = np.mean(sample)
    std_err = np.std(sample, ddof=1) / np.sqrt(len(sample))
    margin = norm.ppf((1 + confidence) / 2) * std_err
    return mean - margin, mean + margin

# Simulate data
np.random.seed(42)
sample = np.random.normal(50, 5, 30)

# Calculate confidence interval
ci_low, ci_high = confidence_interval(sample)
print(f"95% Confidence Interval: ({ci_low:.2f}, {ci_high:.2f})")
# Out:
# 95% Confidence Interval: (47.45, 50.67)

# %%
#10. Write a Python program to calculate the margin of error for a given confidence level using sample data
import numpy as np
from scipy.stats import norm

def margin_of_error(sample, confidence=0.95):
    std_err = np.std(sample, ddof=1) / np.sqrt(len(sample))
    return norm.ppf((1 + confidence) / 2) * std_err

np.random.seed(42)
sample = np.random.normal(50, 5, 30)

# Calculate margin of error
moe = margin_of_error(sample)
print(f"Margin of Error (95% confidence): {moe:.2f}")
# Out:
# Margin of Error (95% confidence): 1.61

# %%
#11. Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process

def bayes_theorem(prior, likelihood, evidence):
    posterior = (likelihood * prior) / evidence
    return posterior

prior = 0.01  # Prior probability of having a rare disease
likelihood = 0.95  # Probability of testing positive given the disease
evidence = (likelihood * prior) + ((1 - prior) * 0.05)  # Total probability of testing positive

posterior = bayes_theorem(prior, likelihood, evidence)
print(f"Posterior Probability: {posterior:.4f}")
# Out:
# Posterior Probability: 0.1610

# %%
#12. Perform a Chi-square test for independence between two categorical variables in Python.

import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency

# Create a contingency table
data = np.array([[30, 10], [20, 40]])  # Example data
contingency_table = pd.DataFrame(data, columns=['Category A', 'Category B'], index=['Group 1', 'Group 2'])

# Perform Chi-square test
chi2_stat, p_value, dof, expected = chi2_contingency(contingency_table)

print(f"Chi-square Statistic: {chi2_stat:.4f}, P-value: {p_value:.4f}")
print("Reject H₀" if p_value < 0.05 else "Fail to reject H₀")
# Out:
# Chi-square Statistic: 15.0417, P-value: 0.0001
# Reject H₀

# %%
#13. Write a Python program to calculate the expected frequencies for a Chi-square test based on observed data.
import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency

# Create a contingency table with observed data
observed = np.array([[30, 10], [20, 40]])  # Example data
contingency_table = pd.DataFrame(observed, columns=['Category A', 'Category B'], index=['Group 1', 'Group 2'])

# Calculate expected frequencies
_, _, _, expected = chi2_contingency(contingency_table)
expected_df = pd.DataFrame(expected, columns=['Category A', 'Category B'], index=['Group 1', 'Group 2'])

print("Expected Frequencies:")
print(expected_df)
# Out:
# Expected Frequencies:
#          Category A  Category B
# Group 1        20.0        20.0
# Group 2        30.0        30.0

# %%
#14. Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution
import numpy as np
from scipy.stats import chisquare

# Observed and expected frequencies
observed = np.array([50, 30, 20])  # Example observed data
expected = np.array([40, 40, 20])  # Expected distribution

# Perform Chi-square goodness-of-fit test
chi2_stat, p_value = chisquare(observed, expected)

print(f"Chi-square Statistic: {chi2_stat:.4f}, P-value: {p_value:.4f}")
print("Reject H₀" if p_value < 0.05 else "Fail to reject H₀")
# Out:
# Chi-square Statistic: 5.0000, P-value: 0.0821
# Fail to reject H₀

# %%
#15. Create a Python script to simulate and visualize the Chi-square distribution and discuss its characteristics.
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Simulate Chi-square distribution
df = 5  # Degrees of freedom
x = np.linspace(0, 20, 1000)
y = stats.chi2.pdf(x, df)

# Plot the Chi-square distribution
plt.figure(figsize=(8, 5))
plt.plot(x, y, label=f'Chi-square (df={df})', color='blue')
plt.fill_between(x, y, alpha=0.2, color='blue')
plt.xlabel("Chi-square value")
plt.ylabel("Probability Density")
plt.title("Chi-square Distribution")
plt.legend()
plt.grid()
plt.show()

# %%
#16. Implement an F-test using Python to compare the variances of two random samples
import numpy as np
from scipy.stats import f

# Generate two random samples
np.random.seed(42)
sample1 = np.random.normal(50, 10, 30)
sample2 = np.random.normal(50, 15, 30)

# Calculate sample variances
var1 = np.var(sample1, ddof=1)
var2 = np.var(sample2, ddof=1)

# Compute F-statistic
f_stat = var1 / var2 if var1 > var2 else var2 / var1

df1 = len(sample1) - 1
df2 = len(sample2) - 1
p_value = 1 - f.cdf(f_stat, df1, df2)

print(f"F-test: F-statistic = {f_stat:.4f}, P-value = {p_value:.4f}")
print("Reject H₀" if p_value < 0.05 else "Fail to reject H₀")
# Out:
# F-test: F-statistic = 2.4082, P-value = 0.0104
# Reject H₀

# %%
#17. Write a Python program to perform an ANOVA test to compare means between multiple groups and interpret the results
import numpy as np
from scipy.stats import f_oneway

# Generate random samples for three groups
np.random.seed(42)
group1 = np.random.normal(50, 10, 30)
group2 = np.random.normal(55, 10, 30)
group3 = np.random.normal(60, 10, 30)

# Perform ANOVA test
f_stat, p_value = f_oneway(group1, group2, group3)

# Print results
print(f"ANOVA Test: F-statistic = {f_stat:.4f}, P-value = {p_value:.4f}")
print("Reject H₀: Significant difference between groups" if p_value < 0.05 else "Fail to reject H₀: No significant difference between groups")
# Out:
# ANOVA Test: F-statistic = 12.2095, P-value = 0.0000
# Reject H₀: Significant difference between groups

# %%
#18. Perform a one-way ANOVA test using Python to compare the means of different groups and plot the results
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import f_oneway

# Generate random samples for three groups
np.random.seed(42)
group1 = np.random.normal(50, 10, 30)
group2 = np.random.normal(55, 10, 30)
group3 = np.random.normal(60, 10, 30)

# Perform ANOVA test
f_stat, p_value = f_oneway(group1, group2, group3)

print(f"ANOVA Test: F-statistic = {f_stat:.4f}, P-value = {p_value:.4f}")
print("Reject H₀: Significant difference between groups" if p_value < 0.05 else "Fail to reject H₀: No significant difference between groups")

# Plot results
plt.boxplot([group1, group2, group3], labels=['Group 1', 'Group 2', 'Group 3'])
plt.ylabel("Values")
plt.title("One-Way ANOVA Test - Group Comparison")
plt.grid()
plt.show()
# Out:
# ANOVA Test: F-statistic = 12.2095, P-value = 0.0000
# Reject H₀: Significant difference between groups
# <ipython-input-19-fc2717077ef0>:19: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([group1, group2, group3], labels=['Group 1', 'Group 2', 'Group 3'])

# %%
#19. Write a Python function to check the assumptions (normality, independence, and equal variance) for ANOVA
import numpy as np
from scipy.stats import shapiro, levene

def check_anova_assumptions(*groups):
    for i, g in enumerate(groups, 1):
        print(f"Group {i} Normality: P = {shapiro(g).pvalue:.4f}")
    print(f"Equal Variance: P = {levene(*groups).pvalue:.4f}")
    print("Ensure independence in data collection.")

np.random.seed(42)
groups = [np.random.normal(50 + i*5, 10, 30) for i in range(3)]
check_anova_assumptions(*groups)
# Out:
# Group 1 Normality: P = 0.6868
# Group 2 Normality: P = 0.9130
# Group 3 Normality: P = 0.3654
# Equal Variance: P = 0.8627
# Ensure independence in data collection.

# %%
#20. Perform a two-way ANOVA test using Python to study the interaction between two factors and visualize the results
import numpy as np
import pandas as pd
from statsmodels.formula.api import ols
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt

# Generate random data
np.random.seed(42)
data = pd.DataFrame({
    'A': np.tile(['A1', 'A2'], 30),
    'B': np.repeat(['B1', 'B2', 'B3'], 20),
    'Y': np.random.normal(50, 10, 60)
})

# Two-way ANOVA
model = ols('Y ~ C(A) * C(B)', data).fit()
print(sm.stats.anova_lm(model, typ=2))

# Interaction plot
sns.pointplot(x='A', y='Y', hue='B', data=data)
plt.show()
# Out:
#                 sum_sq    df         F    PR(>F)
# C(A)          0.661767   1.0  0.007466  0.931463
# C(B)         58.088244   2.0  0.327679  0.722017
# C(A):C(B)    24.838159   2.0  0.140114  0.869575
# Residual   4786.334528  54.0       NaN       NaN

# %%
#21. Write a Python program to visualize the F-distribution and discuss its use in hypothesis testing
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Generate F-distribution data
df1, df2 = 5, 10  # Degrees of freedom
x = np.linspace(0, 5, 1000)
y = stats.f.pdf(x, df1, df2)

# Plot F-distribution
plt.figure(figsize=(8, 5))
plt.plot(x, y, label=f'F-distribution (df1={df1}, df2={df2})', color='blue')
plt.fill_between(x, y, alpha=0.2, color='blue')
plt.xlabel("F-value")
plt.ylabel("Probability Density")
plt.title("F-Distribution in Hypothesis Testing")
plt.legend()
plt.grid()
plt.show()

# %%
#22. Perform a one-way ANOVA test in Python and visualize the results with boxplots to compare group means
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from scipy.stats import f_oneway

# Generate random samples
np.random.seed(42)
groups = [np.random.normal(50 + i * 5, 10, 30) for i in range(3)]

# ANOVA test
f_stat, p_value = f_oneway(*groups)
print(f"F = {f_stat:.4f}, P = {p_value:.4f}")

# Boxplot visualization
sns.boxplot(data=groups)
plt.xticks(ticks=[0, 1, 2], labels=['Group 1', 'Group 2', 'Group 3'])
plt.title("One-Way ANOVA")
plt.grid()
plt.show()
# Out:
# F = 12.2095, P = 0.0000

# %%
#23. Simulate random data from a normal distribution, then perform hypothesis testing to evaluate the means
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from scipy.stats import ttest_ind

# Generate random normal data
np.random.seed(42)
group1 = np.random.normal(50, 10, 30)
group2 = np.random.normal(55, 10, 30)

# Perform hypothesis testing (t-test)
t_stat, p_value = ttest_ind(group1, group2)
print(f"T = {t_stat:.4f}, P = {p_value:.4f}")

# Boxplot visualization
sns.boxplot(data=[group1, group2])
plt.xticks(ticks=[0, 1], labels=['Group 1', 'Group 2'])
plt.title("Hypothesis Testing: Mean Comparison")
plt.grid()
plt.show()
# Out:
# T = -2.3981, P = 0.0197

# %%
#24. Perform a hypothesis test for population variance using a Chi-square distribution and interpret the results
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# Generate random normal data
np.random.seed(42)
data = np.random.normal(50, 10, 30)

# Hypothesis test for variance
sample_var = np.var(data, ddof=1)  # Sample variance
pop_var = 100  # Hypothesized population variance
chi_sq_stat = (len(data) - 1) * sample_var / pop_var
p_value = 1 - stats.chi2.cdf(chi_sq_stat, df=len(data) - 1)

print(f"Chi-Square = {chi_sq_stat:.4f}, P = {p_value:.4f}")
print("Reject H₀: Variance differs from population variance" if p_value < 0.05 else "Fail to reject H₀: No significant difference")

# Histogram visualization
sns.histplot(data, bins=10, kde=True)
plt.title("Population Variance Hypothesis Test")
plt.grid()
plt.show()
# Out:
# Chi-Square = 23.4903, P = 0.7536
# Fail to reject H₀: No significant difference

# %%
#25. Write a Python script to perform a Z-test for comparing proportions between two datasets or groups
import numpy as np
import scipy.stats as stats

# Sample data (successes and total observations)
success1, n1 = 45, 100  # Group 1
success2, n2 = 30, 100  # Group 2

# Proportions
p1, p2 = success1 / n1, success2 / n2
p_combined = (success1 + success2) / (n1 + n2)

# Z-test for proportions
se = np.sqrt(p_combined * (1 - p_combined) * (1/n1 + 1/n2))
z_stat = (p1 - p2) / se
p_value = 2 * (1 - stats.norm.cdf(abs(z_stat)))  # Two-tailed test

print(f"Z = {z_stat:.4f}, P = {p_value:.4f}")
print("Reject H₀: Proportions are significantly different" if p_value < 0.05 else "Fail to reject H₀: No significant difference")
# Out:
# Z = 2.1909, P = 0.0285
# Reject H₀: Proportions are significantly different

# %%
#26. Implement an F-test for comparing the variances of two datasets, then interpret and visualize the results
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Generate random data
np.random.seed(42)
group1 = np.random.normal(50, 10, 30)
group2 = np.random.normal(55, 15, 30)

# Compute variances
var1, var2 = np.var(group1, ddof=1), np.var(group2, ddof=1)

# Perform F-test
f_stat = var1 / var2
df1, df2 = len(group1) - 1, len(group2) - 1
p_value = 2 * min(stats.f.cdf(f_stat, df1, df2), 1 - stats.f.cdf(f_stat, df1, df2))

print(f"F = {f_stat:.4f}, P = {p_value:.4f}")
print("Reject H₀: Variances are significantly different" if p_value < 0.05 else "Fail to reject H₀: No significant difference")

plt.boxplot([group1, group2], labels=['Group 1', 'Group 2'])
plt.title("F-Test: Variance Comparison")
plt.grid()
plt.show()
# Out:
# F = 0.4153, P = 0.0209
# Reject H₀: Variances are significantly different
# <ipython-input-27-f9591d9d2c32>:22: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([group1, group2], labels=['Group 1', 'Group 2'])

# %%
#27. Perform a Chi-square test for goodness of fit with simulated data and analyze the results.
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Simulated observed data
observed = np.array([50, 30, 20])
expected = np.array([40, 40, 20])  # Hypothetical expected distribution

# Perform Chi-square goodness of fit test
chi_sq_stat, p_value = stats.chisquare(observed, expected)

print(f"Chi-Square = {chi_sq_stat:.4f}, P = {p_value:.4f}")
print("Reject H₀: Observed distribution significantly differs from expected" if p_value < 0.05 else "Fail to reject H₀: No significant difference")

labels = ['Category 1', 'Category 2', 'Category 3']
x = np.arange(len(labels))
width = 0.4

plt.bar(x - width/2, observed, width, label='Observed', alpha=0.7)
plt.bar(x + width/2, expected, width, label='Expected', alpha=0.7)
plt.xticks(ticks=x, labels=labels)
plt.title("Chi-Square Goodness of Fit Test")
plt.legend()
plt.grid()
plt.show()
# Out:
# Chi-Square = 5.0000, P = 0.0821
# Fail to reject H₀: No significant difference
